# %% [markdown]
# <a href="https://colab.research.google.com/github/groovies/cutter/blob/master/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# QUESTION 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def j(w):
  return (w-2.5)**2

# %%
w=np.linspace(-5,10,100)
plt.plot(w,j(w))
plt.ylabel("j(w)")
plt.xlabel("w")
plt.title("cost function")
# Out:
# Text(0.5, 1.0, 'cost function')

# %%
def derivative(w):
  return 2*(w-2.5)

# %%
w=-4
Epochs=100
count=0
lr=0.001
M=[]
while count<Epochs:
  lr=0.01
  w= w-lr * derivative(w)
  M.append(w)
  count +=1

# %%
plt.plot(M)

# %% [markdown]
# QUESTION 2 AND 3

# %%
import pandas as pd
import math
import numpy as np
plt.rcParams['figure.figsize'] = (12.0, 9.0)
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
dataset=pd.read_csv("weightdataset.csv",sep=";")
dataset
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
x=dataset.iloc[:,[2]]
y=dataset.iloc[:,[1]]
plt.scatter(x,y)
plt.ylabel('Height')
plt.xlabel('Weight')
plt.title('height versus weight')
plt.show()

# %%
# Building the model
m=0
c=0

L = 0.001  # The learning Rate
epochs = 10000  # The number of iterations to perform gradient descent

n = 1 # Number of elements 

# Performing Gradient Descent 
for i in range(epochs): 
    y_pred = m*x + c  # The current predicted value of Y
    D_m = (-2/n) * np.sum(x * (y - y_pred))  # Derivative wrt m
    D_c = (-2/n) * np.sum(y - y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print(m,c)
# Out:
# Height    0.0
# Weight    0.0
# dtype: float64 Height    0.0
# Weight    0.0
# dtype: float64

# %%
 #Making predictions
y_pred = m*x + c

plt.scatter(x, y) 
plt.plot([min(x), max(x)], [min(y_pred), max(y_pred)], color='red')  # regression line
plt.show()
